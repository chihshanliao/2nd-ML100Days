# %% [markdown]
# ## 作業一 : 請上 Kaggle，在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#  ## 1. 你選的這組資料為何重要
#  ## 我選擇的資料集是在Kaggle的 Dataset 中，名稱為” Fact-Checking Facebook Politics Pages Hyperpartisan Facebook pages and misleading information during the 2016 election “，因為在2016年美國總統大選期間，在Facebook粉絲專業中，某些超越黨派的粉絲專業和誤導性的訊息，以驚人的速度在網路上擴散。所以，個人覺得 “假新聞 Fake News” 是一個很值得討論且符合公眾利益的題目。
#  ## 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#  ## 提供者是 BuzzFeed News。BuzzFeed News分析了來自右翼，左翼和主流媒體的超黨派政治Facebook頁面的1000多個故事，以確定他們共享的虛假或誤導性信息的性質和受歡迎程度。
#  ## 3. 蒐集而來的資料型態為何
#  ## 資料型態為結構化的CSV，可以下載的檔名為facebook-fact-check.csv。欄位有 : account_id, post_id, Category, Page, Post URL, Date Published, Post Type, Rating, Debate, share_count, reaction_count, comment_count.
#  ## 4. 蒐集而來的資料型態為何
#  ## 想要了解在Facebook上探索超黨派迴聲室的一些想法：左派，主流和正確類別的Facebook頁面在他們分享的故事中有何不同？BuzzFeed News要求每個評估者在不同的日子里分別從每個類別中選擇一頁。在某些情況下，BuzzFeed News發現網頁會在24小時內重新發布相同的鏈接或視頻，這會導致Facebook為其分配相同的網址。發生這種情況時，BuzzFeed News沒有記錄或評價重複帖子，而是保留了原始日期和評級。每位評估者都瞭解如何審核帖子的相同指南，評級的分類如下4種 : 最有可能是真的、真假混和、最有可能是假的、沒有實際內容。

# %% [markdown]
# ## 作業二 : 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#  ## 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#  ## 「提升業績」定義 : 藉由數據分析，找出某些特徵或現象，例如某些數據欄位名稱如下，載客地點、客群、時間、交通狀況、路面狀況、天氣、司機素質、車子內裝，等等，藉由將車隊的載客紀錄數據視覺化之後，分析出在那些欄位的組合之下，業績成長率最大的。
#  ## 「我的假設」定義 : 藉由蒐集車隊的載客紀錄中的欄位資訊，假設如果能夠找出某些地點與某些時段是乘客搭車的熱門時段，藉由數據分析之後，可以推薦給車隊的司機當作參考依據。
#  ## 所以，我的問題是透過蒐集車隊的載客紀錄，找出哪些地點與時段的搭配組合是乘客搭車的熱門時段，然後推薦給車隊的司機當作參考依據。
#  ## 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#  ## 透過假設，可以得知載客地點與時段是關鍵因子。
#  ## 可以透過訓練，教導車隊的司機用語音的方式輸入載客紀錄，並開發一個語音轉文字的系統，透過自然語言處理的技術將載客紀錄存入系統與資料庫中。
#  ## 3. 蒐集而來的資料型態為何
#  ## 資料型態為結構化的CSV。欄位有 : 載客地點、客群、時間、交通狀況(是否有塞車或交通意外事故)、路面狀況(是否施工)、天氣、司機素質、車子內裝、車子使用年份
#  ## 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#  ## 透過深度學習的技術將地點與時段的搭配組合找出來，並要求車隊的司機配合實施一個星期，比較實施前與實施後，業績是否有上升即可驗證假設是否成立。

# %% [markdown]
# ## 作業三 : 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    
    n = len(y)
    mse = sum(np.square(y - y_hat)) / n
    return mse

def mean_absolute_error(y, y_hat):
    
    n = len(y)
    mae = sum(np.abs(y - y_hat)) / n
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 222.893
# The Mean absolute error is 11.493
